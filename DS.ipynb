# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# In this notebook, we will explore various tools, languages, and libraries used in Data Science. Additionally, we will demonstrate simple arithmetic operations.

# %% [markdown]
# ## Data Science Languages
# Some of the popular languages used in Data Science include:
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# Some of the commonly used libraries in Data Science include:
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - PyTorch

# %% [markdown]
# ## Data Science Tools
#
# | Tool           | Description                                  |
# |---------------|----------------------------------------------|
# | Jupyter Notebook | Interactive coding environment            |
# | RStudio       | IDE for R programming                        |
# | Apache Spark  | Big data processing framework                |
# | TensorFlow    | Deep learning library                        |
# | Power BI      | Data visualization tool                      |

# %% [markdown]
# ## Arithmetic Expression Examples
# Below, we will demonstrate basic arithmetic operations such as addition and multiplication.

# %% [markdown]
# # Multiplying and adding numbers
# a = 5
# b = 10
# result = (a * b) + 20
# result

# %% [markdown]
# # Convert minutes to hours
# minutes = 150
# hours = minutes / 60
# hours

# %% [markdown]
# ## Objectives
# - Understand different programming languages used in Data Science
# - Learn about Data Science tools and libraries
# - Perform basic arithmetic operations in Python
# - Convert time units using Python
# - Share a Jupyter Notebook through GitHub

# %% [markdown]
# ## Author
# Hamdan

# %% [markdown]
# # Share on GitHub.
# # Save the notebook (.ipynb file).
# # Go to GitHub and create a new repository.
# # Upload the notebook file to the repository.
# # Copy the GitHub link for submission.

# %% [markdown]
# ![image.png](attachment:387d08a9-687b-4404-be4d-28a75c5a285f.png)
